# %% [markdown]
# # Importing Libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# create a path variable
path = r'C:\Users\Sreelakshmi\Desktop\Instacart Basket Analysis'

# %% [markdown]
# ### Import the file orders_products_merged_derived.pkl into the data frame

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_merged_derived.pkl'))

# %%
# create a subset dataframe having 1 million rows
df = ords_prods_merge[:1000000]

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_days_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
# 1                     7.0       14084                  2          0
# 2                     7.0       12427                  3          0
# 3                     7.0       26088                  4          0
# 4                     7.0       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
#
#   _merge    price_range_loc    Busiest_days busiest_period_of_day
# 0   both  Mid-range product  Regularly Busy        Average orders
# 1   both  Mid-range product  Regularly Busy        Average orders
# 2   both  Low-range product  Regularly Busy        Average orders
# 3   both  Low-range product  Regularly Busy        Average orders
# 4   both  Low-range product  Regularly Busy        Average orders

# %% [markdown]
# # Grouping Data with Pandas

# %% [markdown]
# ### 1. Use groupby() function

# %%
# use the groupby function on the column 'product_name'
df.groupby('product_name')

# %% [markdown]
# ### Use agg() function

# %%
# calculate the mean of the “order_number” column grouped by the “department_id” column
df.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %% [markdown]
# ## Another usage of aggregate function

# %%
# calculate the mean of the “order_number” column grouped by the “department_id” column
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %% [markdown]
# ## Using other aggregate functions like min, max

# %%
#  Calculating mean, min and max of order_number for each department_id
df.groupby('department_id').agg({'order_number':['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %% [markdown]
# # Aggregating Data with transform()

# %% [markdown]
# ### 1. Split the data into groups based on the “user_id” column.
# ### 2. Apply the transform() function on the “order_number” column to generate the maximum orders for each user
# ### 3. Create a new column, “max_order,” into which you’ll place the results of your aggregation.

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby('user_id')['order_number'].transform('max')

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  order_days_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# ..       ...      ...           ...                 ...                ...
# 95    738281        2             4                   2                 10
# 96   1673511        2             5                   3                 11
# 97   1673511        2             5                   3                 11
# 98   1673511        2             5                   3                 11
# 99   1673511        2             5                   3                 11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      7.0         196                  1          0
# 1                      7.0       14084                  2          0
# 2                      7.0       12427                  3          0
# 3                      7.0       26088                  4          0
# 4                      7.0       26405                  5          0
# ..                     ...         ...                ...        ...
# 95                     8.0       21150                 13          0
# 96                     8.0       47144                  1          0
# 97                     8.0        5322                  2          0
# 98                     8.0       17224                  3          0
# 99                     8.0       38656                  4          0
#
#                                          product_name  aisle_id  \
# 0                                                Soda        77
# 1             Organic Unsweetened Vanilla Almond Milk        91
# 2                                 Original Beef Jerky        23
# 3                          Aged White Cheddar Popcorn        23
# 4                    XL Pick-A-Size Paper Towel Rolls        54
# ..                                                ...       ...
# 95                            Fire Grilled Steak Bowl        38
# 96     Unsweetened Original Almond Breeze Almond Milk        91
# 97  Gluten Free Dark Chocolate Chunk Chewy with a ...         3
# 98                   Oats & Honey Gluten Free Granola         3
# 99  Gluten Free Peanut Butter Dark Chocolate Chewy...         3
#
#     department_id  prices _merge    price_range_loc     Busiest_days  \
# 0               7     9.0   both  Mid-range product   Regularly Busy
# 1              16    12.5   both  Mid-range product   Regularly Busy
# 2              19     4.4   both  Low-range product   Regularly Busy
# 3              19     4.7   both  Low-range product   Regularly Busy
# 4              17     1.0   both  Low-range product   Regularly Busy
# ..            ...     ...    ...                ...              ...
# 95              1     5.9   both  Mid-range product   Regularly Busy
# 96             16    14.0   both  Mid-range product  Least Busy Days
# 97             19     2.9   both  Low-range product  Least Busy Days
# 98             19     1.6   both  Low-range product  Least Busy Days
# 99             19     3.4   both  Low-range product  Least Busy Days
#
#    busiest_period_of_day  max_order
# 0         Average orders         10
# 1         Average orders         10
# 2         Average orders         10
# 3         Average orders         10
# 4         Average orders         10
# ..                   ...        ...
# 95           Most orders         14
# 96           Most orders         14
# 97           Most orders         14
# 98           Most orders         14
# 99           Most orders         14
#
# [100 rows x 18 columns]

# %% [markdown]
# ## Command to remove the restriction of displaying the rows in Jupyter Notebook

# %%
# pd.options.display.max_rows = None

# %% [markdown]
# # Deriving Columns with loc()

# %%
# use the loc function for filtering the data

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40 , 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10 , 'loyalty_flag'] = 'New customer'

# %%
# check the frequency of the newly created column loyalty_flag
ords_prods_merge['loyalty_flag'].value_counts()
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# displaying first 60 rows of user_id, loyalty_flag and order number
ords_prods_merge[['user_id','loyalty_flag','order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# 20        1      New customer             4
# 21        1      New customer             5
# 22        1      New customer             5
# 23        1      New customer             5
# 24        1      New customer             5
# 25        1      New customer             5
# 26        1      New customer             5
# 27        1      New customer             5
# 28        1      New customer             5
# 29        1      New customer             6
# 30        1      New customer             6
# 31        1      New customer             6
# 32        1      New customer             6
# 33        1      New customer             7
# 34        1      New customer             7
# 35        1      New customer             7
# 36        1      New customer             7
# 37        1      New customer             7
# 38        1      New customer             8
# 39        1      New customer             8
# 40        1      New customer             8
# 41        1      New customer             8
# 42        1      New customer             8
# 43        1      New customer             8
# 44        1      New customer             9
# 45        1      New customer             9
# 46        1      New customer             9
# 47        1      New customer             9
# 48        1      New customer             9
# 49        1      New customer             9
# 50        1      New customer            10
# 51        1      New customer            10
# 52        1      New customer            10
# 53        1      New customer            10
# 54        1      New customer            10
# 55        1      New customer            10
# 56        1      New customer            10
# 57        1      New customer            10
# 58        1      New customer            10
# 59        2  Regular customer             1
